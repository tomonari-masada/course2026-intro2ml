# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonari-masada/course2026-intro2ml/blob/main/05_NumPy_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # NumPy入門 (1)

# %% [markdown]
# * NumPyを説明する前に・・・

# %% [markdown]
# ## モジュール、パッケージ、ライブラリ
# * 参考資料
#   * https://zenn.dev/delacroix/articles/e3f62ca001deb0

# %% [markdown]
# * モジュール
#   * Pythonのファイル(.pyファイル)のこと。
#   * `import`文で.pyファイルをインポートすることで、その.pyファイルの中の関数やクラスを使用することができるようになる。
# * パッケージ
#   * モジュールを複数集めたものです。
#   * つまり .pyファイルを複数置いてあるフォルダのようなもの。
#   * 言葉としては、次の「ライブラリ」と区別せずに使われることもある。
#     * Python Package Index https://pypi.org/
# * ライブラリ
#   * 複数のパッケージからなるPythonコードの集合体。
#   * 標準ライブラリと外部ライブラリがある。
#   * 標準ライブラリは、Pythonにはじめからくっついてくるライブラリ。

# %% [markdown]
# ## mathモジュール
# * Pythonでは数学的な処理をするためのモジュールがいくつか用意されている。
#   * https://docs.python.org/ja/3.13/library/numeric.html

# %%
import math

a = 2.0

# %%
b = math.sqrt(a)
print(a, b)

# %%
c = math.exp(a)
print(a, c)

# %% [markdown]
# # NumPyライブラリ

# %% [markdown]
# * ベクトルや行列を扱える（他にも様々な機能がある）
#  * ベクトルどうしの内積
#  * 行列とベクトルの積
#  * 行列と行列の積
#  * 逆行列
#
# * ndarrayという独自のデータ構造を使う
#  * ちゃんとコードを書けば高速（ちゃんと書かないと遅い・・・）

# %% [markdown]
# ## NumPyの配列(ndarray)の作り方

# %% [markdown]
# ### Pythonのリストから作る

# %%
import numpy as np

# %% [markdown]
# * 一次元配列

# %%
a = np.array([-2.0, 1.0, 3.0])
print(a)

# %% [markdown]
# * 二次元配列

# %%
b = np.array([[1,2,3], [4,5,6]])
print(b)

# %% [markdown]
# * 転置

# %%
print(a.T)

# %%
print(b.T)

# %% [markdown]
# ### ndarrayの演算

# %%
a = np.array([1, 2, 3])
print(a)

# %%
print(a * 3)

# %%
c = a * 3
print(c)

# %%
b = np.array([2, 2, 0])
print(b)

# %%
print(a + b)

# %%
print(a * b)

# %%
print(a / b) #エラーが出る（どんなエラー？）

# %% [markdown]
# * ベクトルの内積

# %%
print(np.dot(a, b))

# %% [markdown]
# ### ndarrayの属性

# %%
a = np.array([-2.0, 1.0, 3.0])
b = np.array([[1, 2, 3], [4, 5, 6]])

# %% [markdown]
# * 配列自体のデータ型

# %%
print(type(a))

# %% [markdown]
# * 配列の要素のデータ型
#   * つまり配列の中身のデータ型

# %%
print(a.dtype)

# %% [markdown]
# * 配列のサイズ

# %%
print(a.size, b.size)

# %% [markdown]
# * 配列の要素のサイズ

# %%
print(a.itemsize, b.itemsize)

# %% [markdown]
# * 次元数

# %%
print(a.ndim, b.ndim)

# %% [markdown]
# * 形状

# %%
print(a.shape, b.shape)

# %% [markdown]
# ### ndarrayの作り方のいろいろ

# %%
a = np.arange(10)
print(a)

# %%
b = np.arange(0, 10, 2)
print(b)

# %%
x = np.linspace(0, 10, 15) #0以上10以下を14等分
print(x)

# %% [markdown]
# * 配列を乱数で埋める

# %%
print(np.random.randn()) #正規乱数
a = np.random.randn(2, 3)
print(a)

# %%
b = np.random.randn(3, 4)
print(b)
print(np.dot(a, b))

# %% [markdown]
# * 次のセルはエラーになる。
#   * なぜ？

# %%
print(np.dot(b, a))

# %% [markdown]
# * 配列をゼロやその他の数値で埋める

# %%
a = np.zeros((3,3)) #()で囲む必要あり
print(a)

# %%
b = np.ones((3,3))
print(b)

# %% [markdown]
# * 問：次のセルの出力結果がなぜそうなるか、説明してみよう。

# %%
print(np.dot(b, b))

# %%
c = np.full((2,2), 7)
print(c)

# %% [markdown]
# ## 配列の要素を指定する

# %% [markdown]
# ### インデックス（添え字）

# %%
a = np.arange(1, 20, 3)
print(a)

# %%
print(a[0])
print(a[1])

# %%
a[3] = 11
print(a)

# %% [markdown]
# * 2次元配列の場合

# %%
c = np.array([[1,2,3],[4,5,6]])
print(c)

# %%
print(c[0,0])
print(c[0,2])
print(c[1,2])

# %% [markdown]
# ## ndarrayを高速に扱う工夫
# * 要素を個別に取り出して計算したりしない。

# %%
import time
import numpy as np

x = np.ones(10000000)
y = np.ones(10000000)
s = np.zeros(10000000)
for _ in range(10):
  a = time.time()
  for i in range(10000000):
    s[i] = x[i] + y[i]
  b = time.time()
  print(b - a)

# %% [markdown]
# * 上のセルのように書くより、こう書くほうが良い

# %%
import time
import numpy as np

x = np.ones(10000000)
y = np.ones(10000000)
s = np.zeros(10000000)
for _ in range(10):
  a = time.time()
  s = x + y
  b = time.time()
  print(b - a)

# %% [markdown]
# ## スライシング
# * 配列の要素をまとめて扱う。

# %%
a = np.arange(1, 20, 3)
print(a)

# %%
print(a[1:5])

# %%
print(a[0:6:2])

# %%
print(a[::-1])

# %%
print(a[-2::-1])

# %%
print(a[-2:1:-1])

# %% [markdown]
# ### fancy index

# %%
np.random.seed(1234)
a = np.random.randint(10, size=10)
print(a)

# %%
m = a % 3 == 0
print(m)

# %%
print(type(m))
print(m.dtype)

# %%
b = a[m]
print(b)

# %% [markdown]
# ### where関数

# %%
np.random.seed(1234)
a = np.random.randint(10,size=10)
print(a)

# %%
m = np.where(a % 2 == 0) #インデックスのtupleを返す
print(m)
print(type(m))

# %%
b = a[m]
print(b)

# %%
np.random.seed(1234)
a = np.random.randint(10,size=10)
print(a)

# %%
m = np.where(a % 2 == 0, 'even', 'odd')
print(m)

# %%
print(a[m == 'even'])

# %% [markdown]
# ## 配列のコピー

# %% [markdown]
# ### 配列のビュー
# * 中身をコピーするわけではない。

# %%
a = np.array([1, 2, 3])
b = a #ビューを作っている

# %% [markdown]
# ### リストのコピー

# %%
a = [1, 2, 3]
b = a
b[1] = 22
print(a)
print(b)

# %%
c = a[:] #リストがコピーされる
c[2] = 234
print(a)
print(c)

# %% [markdown]
# ### ndarrayの場合の`a[:]`
# * コピーされるかどうか？

# %%
a = np.array([1, 2, 3])
c = a[:]

# %%
print(id(a) == id(c))

# %%
c[1] = 22
print(a) #変化している

# %% [markdown]
# ### `copy`メソッド

# %%
a = np.array([1, 2, 3])
d = a.copy() #コピーを作る
print(id(a) == id(d))

# %%
d[2] = 234
print(a) #変化していない

# %% [markdown]
# ## 配列の形の変更

# %%
a = np.arange(12)
print(a)

# %% [markdown]
# * NumPyのreshape関数

# %%
b = np.reshape(a, (3, 4)) #
print(b)

# %% [markdown]
# * 元の配列の中身を変更してみる。

# %%
a[3] = - a[3]
print(a)

# %% [markdown]
# * 注意: reshape関数は配列の中身をコピーしない。

# %%
print(b) #中身が変化している!

# %% [markdown]
# * ndarrayのreshapeメソッド

# %%
c = a.reshape((2,6))
print(c)

# %% [markdown]
# # 課題20250519
# * 1から1000までの範囲のすべての偶数の和を求める計算を、NumPyの機能を使って書いてみよう。
#   * NumPyの配列を使う、NumPyのarangeを使う、などなど。とにかく、何か一つでもNumPyの機能を使ってください。
