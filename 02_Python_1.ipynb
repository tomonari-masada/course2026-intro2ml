# %% [markdown]
# <a href="https://colab.research.google.com/github/tomonari-masada/course2026-intro2ml/blob/main/02_Python_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python入門 (1)
# * 「Pythonのコードなんて、生成AIに書いてもらえばいいんじゃないの？」
#   * こういう疑問に、あなたならどう答えますか？

# %% [markdown]
# ## Google Colabでコードを実行する

# %% [markdown]
# ### 変数への値の設定

# %%
a = 3.1

# %% [markdown]
# ### 変数の内容の確認

# %%
a

# %% [markdown]
# ### コメント
# * ハッシュ記号（`#`）以下の文字列はコードの実行に無関係
#   * コードの説明などを書いておくとよい。

# %%
a #コメント

# %% [markdown]
# ### 簡単な計算

# %%
b = 2.4

# %%
b

# %%
a + b

# %%
c = a + b

# %%
c

# %% [markdown]
# ### 計算結果を元の変数に上書きする計算
# * in-place演算という。

# %%
c = 5
c += 1

# %%
c

# %% [markdown]
# ## print関数

# %% [markdown]
# * 画面にさまざまな情報を表示させるときに使う。

# %%
print('Hello!')

# %%
print('World!')

# %% [markdown]
# * コンマを使うと、たくさんのものを同時に表示させることができる。
#   * あいだに空白文字が一つ入る。

# %%
print('Hello', 'world!')

# %% [markdown]
# * print関数に変数を与えると、変数の内容が表示される。

# %%
a = 1
b = -1
print(a, b)
print(b, a)

# %% [markdown]
# ## Pythonのオブジェクト

# %% [markdown]
# ### オブジェクト (object)
# * Pythonのプログラムによって操作されるデータのこと。
# * すべてのオブジェクトは型(type)をもつ。

# %% [markdown]
# ### 型 (type) の大別
# * スカラ (scalar): 分割不能なデータ。int型、float型、bool型、None型など。
# * 非スカラ (non-scalar): 内部構造を持つ。例えば、文字列型、リスト型など。

# %% [markdown]
# ### スカラ・オブジェクトの4つの型
# * int型

# %%
print(3)

# %%
print(type(3))

# %% [markdown]
# * float型

# %%
print(3.0)

# %%
print(type(3.0))

# %% [markdown]
# * bool型
#   * TrueとFalseの二種類の値しかない

# %%
print(3 != 2)

# %%
print(type(3 != 2))

# %%
a = 10
b = 4
print(a > b)
print(a < b)

# %%
a = 3
b = 2
print(a == (b + 1))

# %% [markdown]
# * None型
#   * Noneという一種類の値しかない

# %%
a = None

# %%
print(a)

# %%
print(a is None)

# %% [markdown]
# ## 演算子

# %% [markdown]
# ### Pythonの演算子の一覧
#
#
# * +, -, \*, //, /, %, \*\*, ==, !=, >, >=, <, <=
#
# * and, or, not

# %% [markdown]
# ### 算術演算子

# %%
print(3 + 2)

# %%
print(3.0 + 2.0)

# %%
print(3 != 2)

# %% [markdown]
# ### **問題** //と/の違いは？

# %%
print(5 // 2)
print(5 / 2)

# %% [markdown]
# ### 論理演算子
# * bool型のオブジェクトに使う演算子。

# %%
a = 1
b = 3

# %%
print(a == 1)

# %%
print(not a == 1)

# %%
print(a > 2 and b > 2)

# %%
print(a > 2 or b > 2)

# %% [markdown]
# ### 演算子の優先順位
# * 演算子には、どれが先に実行されるかの、優先順位がある。
#   * https://docs.python.org/ja/3/reference/expressions.html#operator-precedence

# %%
print((5 + 2) * 4)
print(5 + 2 * 4)

# %%
print(3 // (2 + 1))
print(3 // 2 + 1)

# %% [markdown]
# ## 変数と代入

# %% [markdown]
# ### Pythonでの代入
# * 変数に値を「紐付けする」イメージ。
#   * 「名前がついた箱に値を入れる」というイメージで考えていると「？？？」と感じることが多い。

# %%
a = 3

# %%
a

# %%
print(a)

# %% [markdown]
# ### 変数名の付け方
# * 使える文字
#   * 大文字、小文字、数字、アンダースコア（`_`）
# * 変数名の注意事項
#   * 大文字と小文字は区別される。
#   * 予約語(reserved word)は変数名として使えない。
# > and, as, assert, break, class, continue, def, del, elif, else, except, False, finally, for, from, global, if, import, in, is, lambda, nonlocal, None, not, or, pass, raise, return, True, try, while, with, yield

# %%
my_integer = 5
my_integer

# %% [markdown]
# ### 複数の代入を1つの文で

# %%
a, b = 5, 4  #aと5, bと4が紐付けされる
print(a, b)

# %% [markdown]
# * 問: 次のセルを実行すると、何が表示されるか？

# %%
a, b = 5, 4
a, b = b, a
print(a, b)

# %% [markdown]
# ## 組み込み関数id
# * オブジェクトの固有識別子が得られる。
#   * オブジェクトに付けられた通し番号のようなもの。
#   * これが同じだと、実体としても同じ。
# * 値として見ると同じでも、固有識別番号は異なることがある。

# %%
a = 2
print(id(a))

# %%
id(2)

# %%
b = 1 + 1
print(id(b))

# %%
c = 1.3
print(id(c))

# %%
d = c
print(id(d))

# %% [markdown]
# * 値としては同じだが固有識別番号は異なる例

# %%
e = c * 1.0
print(id(c))
print(id(e))

# %% [markdown]
# ## if文

# %%
x = 251
if x % 2 == 1:
    print('odd')

# %% [markdown]
# ### else節

# %%
x = 251
if x % 2 == 1:
    print('odd')
else:
    print('even')

# %% [markdown]
# ### elif
# * else ifを略したもの。

# %%
y = 50
if y > 0:
    print('positive')
elif y < 0:
    print('negative')
else:
    print('zero')

# %% [markdown]
# ### 入れ子状のif文
# * if文の中にさらにif文を書くことができる。

# %%
x = 33 # ここの値をいろいろ変えてみる。

if x % 3 == 0:
  if x % 5 == 0:
    print('3と5で割り切れる')
  else:
    print('3で割り切れるが5で割り切れない')
elif x % 5 == 0:
  print('5で割り切れるが3で割り切れない')
else:
  print('3でも5でも割り切れない')

# %% [markdown]
# ## 文字列型（str型）
# * スカラ・オブジェクトではない。
#   * つまり、分割できないデータとはみなせない。
# * たくさんの文字が並んで構成されたデータ。

# %%
print('This is a pen.')

# %% [markdown]
# ### 代入

# %%
s1 = "This is a pen."
s2 = "That is a pencil."
print(s1)
print(s2)

# %% [markdown]
# ### 同じ文字列かどうかの判定

# %%
s1 == s2

# %% [markdown]
# ### 文字列の連結

# %%
s1 = "This is a pen."
s2 = "That is a pencil."
s3 = s1 + s2
print(s3)

# %%
s4 = s1 + " " + s2
print(s4)

# %% [markdown]
# ### 文字列の繰り返し
#   * 整数を掛ける、という書き方をする。

# %%
ss = 'abc'
print(ss)
ss = ss * 10 # 変数ssに上書きしている
print(ss)

# %% [markdown]
# ### 空の文字列

# %%
my_str = ""
print(my_str)

# %%
my_str += "bank"
print(my_str)

# %%
my_str += ""
print(my_str)

# %%
my_str += "rupt"
print(my_str)

# %% [markdown]
# ### 数値を文字列に変換

# %%
my_int = -12425
my_string = str(my_int)
print(my_string)
print(len(my_string))

# %%
my_float = 3.1416
my_string = str(my_float)
print(my_string)
print(len(my_string))

# %% [markdown]
# ## 順序型としての文字列型
# * 同じ種類のアイテムがたくさん並んで構成されるデータの型を順序型という。
# * 順序型には、以下の三種類の操作が、共通している
#   * 長さ
#   * 添え字
#   * スライシング

# %%
s = 'abcdef'

# %% [markdown]
# ### 文字列の長さ

# %%
print(len(s))

# %% [markdown]
# ### 添え字(index)

# %%
print(s[0])

# %%
print(s[3])

# %% [markdown]
# ### スライシング (slicing)

# %%
print(s[2:4])

# %% [markdown]
# ## フォーマット付きprint
# * `f`で始まる文字列は、書式を表現している。
#   * 波括弧の中に、表示したい値や変数を書く。

# %%
a = 0.00215332634
print(a)

# %%
print(f'a = {a}')

# %% [markdown]
# * 指定した桁数で端数を四捨五入

# %%
print(f'a = {a:.4f}')

# %% [markdown]
# * 数値の指数表記

# %%
print(f'a = {a:.4e}')

# %% [markdown]
# ## while文
# * Pythonでは繰り返し処理が書ける。

# %%
counter = 10
while counter > 0:
  print(counter)
  counter = counter - 1

# %%
s = 0
n = 1
while n <= 10:
  s += n
  n += 1
print(s)

# %% [markdown]
# * 無限ループを実行してしまったら・・・
#   * Google Colabでは、セル左端の停止ボタンをクリックすれば処理が止まる。

# %%
a = 1
while True:
  a = 1 - a

# %% [markdown]
# ## break文
# * ループから強制的に抜ける。

# %%
s = 0
n = 1
while True:
  if n > 10:
    break
  s += n
  n += 1
print(s)

# %% [markdown]
# # 課題20260427
# * 下記のコードを、コメントにある指示に従って完成させよう。
# * notebookへのリンク（つまりURL）を、Google Formから提出してください。

# %%
text = "wow"
a = 5

if a >= 0:
  # 変数textに設定された文字列を、変数aに設定された値の回数だけ表示する。
  # ただし、繰り返して表示するときに、空白文字ひとつ分、あいだをあけること。
else:
  print("負の値は設定しないでください。")
